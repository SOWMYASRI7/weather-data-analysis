# %% [markdown]
# <a href="https://colab.research.google.com/github/SOWMYASRI7/weather-data-analysis/blob/main/weather_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

data = pd.read_csv(r"Weather Data.csv")
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# **Basic information of Dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# **Shows the first N rows in the data (by default,5 no's)**

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# **Different Weather conditions available in weather dataset**

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# ***Counts the occurrences of unique values in the 'Weather' column of a DataFrame ***

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# **To find the number of times the weather was clear**

# %%
data[(data.Weather=='Clear')].count()[1]
# Out:
# 1326

# %% [markdown]
# **Finds the number times when the "wind speed is exactly 4km/hr.**

# %%
data[data["Wind Speed_km/h"]==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# find all unique values of "wind speed"

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# **Get weather and temperature columns from the dataframe**

# %%
data[['Weather','Temp_C']].head()
# Out:
#                 Weather  Temp_C
# 0                   Fog    -1.8
# 1                   Fog    -1.8
# 2  Freezing Drizzle,Fog    -1.8
# 3  Freezing Drizzle,Fog    -1.5
# 4                   Fog    -1.5

# %% [markdown]
# **It extract the pressure values for January 6th and prints the first 5 values.**

# %%
data['Date/Time'] = pd.to_datetime(data['Date/Time'])
jan_6_data = data[data['Date/Time'].dt.month == 1]
jan_6_data = jan_6_data[jan_6_data['Date/Time'].dt.day == 6]
first_5_pressure_values = jan_6_data['Press_kPa'].head(5)
print(first_5_pressure_values)
# Out:
# 120    100.81
# 121    100.81
# 122    100.84
# 123    100.76
# 124    100.70
# Name: Press_kPa, dtype: float64

# %% [markdown]
# **Finds all instances when wind speed was above 30 and visibility was 25**

# %%
data[(data['Wind Speed_km/h']>30) & (data['Visibility_km']==25)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 24   2012-01-02 00:00:00     5.2               1.5         77
# 25   2012-01-02 01:00:00     4.6               0.0         72
# 26   2012-01-02 02:00:00     3.9              -0.9         71
# 27   2012-01-02 03:00:00     3.7              -1.5         69
# 28   2012-01-02 04:00:00     2.9              -2.3         69
# ...                  ...     ...               ...        ...
# 8407 2012-12-16 07:00:00    -9.8             -14.9         66
# 8538 2012-12-21 18:00:00     1.4               0.3         92
# 8569 2012-12-23 01:00:00    -7.9             -11.8         74
# 8659 2012-12-26 19:00:00    -9.6             -13.1         76
# 8662 2012-12-26 22:00:00    -9.7             -12.8         78
#
#       Wind Speed_km/h  Visibility_km  Press_kPa        Weather
# 24                 35           25.0      99.26   Rain Showers
# 25                 39           25.0      99.26         Cloudy
# ...

# %% [markdown]
# **To categorize climate factors based on temperature, wind speed, and pressure for each row of a dataset.**

# %%
import pandas as pd
data = pd.read_csv('Weather Data.csv')
def categorize_climate_factors(row):
    factors = []
    # Check temperature
    if row['Temp_C'] > 25:
        factors.append('High temperature')
    elif row['Temp_C'] < 5:
        factors.append('Low temperature')
    # Check wind speed
    if row['Wind Speed_km/h'] > 20:
        factors.append('High wind speed')
    # Check pressure
    if row['Press_kPa'] < 95:
        factors.append('Low pressure')
    return factors
# Apply the function to each row of the DataFrame to categorize climate factors
data['Climate_Factors'] = data.apply(categorize_climate_factors, axis=1)

# Display the DataFrame with categorized climate factors
print(data[['Date/Time', 'Climate_Factors']])
# Out:
#              Date/Time                     Climate_Factors
# 0        1/1/2012 0:00                   [Low temperature]
# 1        1/1/2012 1:00                   [Low temperature]
# 2        1/1/2012 2:00                   [Low temperature]
# 3        1/1/2012 3:00                   [Low temperature]
# 4        1/1/2012 4:00                   [Low temperature]
# ...                ...                                 ...
# 8779  12/31/2012 19:00  [Low temperature, High wind speed]
# 8780  12/31/2012 20:00  [Low temperature, High wind speed]
# 8781  12/31/2012 21:00  [Low temperature, High wind speed]
# 8782  12/31/2012 22:00  [Low temperature, High wind speed]
# 8783  12/31/2012 23:00  [Low temperature, High wind speed]
#
# [8784 rows x 2 columns]

# %% [markdown]
# **climate factors based on temperature, wind speed, and pressure for each entry in a weather dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
data = pd.read_csv('Weather Data.csv')

def categorize_climate_factors(row):
    factors = []
    # Check temperature
    if row['Temp_C'] > 25:
        factors.append('High temperature')
    elif row['Temp_C'] < 5:
        factors.append('Low temperature')
    # Check wind speed
    if row['Wind Speed_km/h'] > 20:
        factors.append('High wind speed')
    # Check pressure
    if row['Press_kPa'] < 95:
        factors.append('Low pressure')
    return factors

data['Climate_Factors'] = data.apply(categorize_climate_factors, axis=1)
# Convert Date/Time column to datetime type
data['Date/Time'] = pd.to_datetime(data['Date/Time'])
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))
# Plot each category of climate factor over time
for factor in data['Climate_Factors'].explode().unique():
    factor_data = data[data['Climate_Factors'].apply(lambda x: factor in x)]
    ax.plot(factor_data['Date/Time'], [factor]*len(factor_data), linestyle='', marker='o', label=factor)
# Set labels and title
ax.set_xlabel('Date/Time')
ax.set_ylabel('Climate Factors')
ax.set_title('Categorized Climate Factors Over Time')
ax.legend()
# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
# Show plot
plt.tight_layout()#gives padding between plot elements
plt.show()
#timeseries plot

# %% [markdown]
# **the trends in temperature variations over time from historical weather data.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the weather dataset into a DataFrame
data = pd.read_csv('Weather Data.csv')

# Convert Date/Time column to datetime type
data['Date/Time'] = pd.to_datetime(data['Date/Time'])

# Extract year and month from Date/Time
data['Year'] = data['Date/Time'].dt.year
data['Month'] = data['Date/Time'].dt.month

# Group by year and month, calculate average temperature
monthly_temp_avg = data.groupby(['Year', 'Month'])['Temp_C'].mean()

# Reset index to access 'Year' and 'Month' as columns
monthly_temp_avg = monthly_temp_avg.reset_index()

# Plotting
plt.figure(figsize=(10, 6))
for year in monthly_temp_avg['Year'].unique():
    year_data = monthly_temp_avg[monthly_temp_avg['Year'] == year]
    plt.plot(year_data['Month'], year_data['Temp_C'], label=year, marker='o')

plt.title('Monthly Average Temperature Variation')
plt.xlabel('Month')
plt.ylabel('Average Temperature (°C)')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Year')
plt.grid(True)
plt.show()

# %% [markdown]
# **Patterns of temperature and humidity variations over time in the provided dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the weather dataset into a DataFrame

data = pd.read_csv('Weather Data.csv')
# Convert Date/Time column to datetime type
data['Date/Time'] = pd.to_datetime(data['Date/Time'])

# Plotting temperature and humidity over time
plt.figure(figsize=(10, 6))
plt.plot(data['Date/Time'], data['Temp_C'], label='Temperature (°C)', color='red')
plt.plot(data['Date/Time'], data['Rel Hum_%'], label='Relative Humidity (%)', color='blue')

# Set labels and title
plt.xlabel('Date/Time')
plt.ylabel('Value')
plt.title('Temperature and Humidity Variation Over Time')
plt.legend()
plt.grid(True)

# Show plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the weather dataset into a DataFrame


data = pd.read_csv('Weather Data.csv')
# Convert Date/Time column to datetime type
data['Date/Time'] = pd.to_datetime(data['Date/Time'])

# Plotting temperature and humidity over time
plt.figure(figsize=(10, 6))
plt.scatter(data['Date/Time'], data['Temp_C'], label='Temperature (°C)', color='red', marker='o', s=5)
plt.scatter(data['Date/Time'], data['Rel Hum_%'], label='Relative Humidity (%)', color='blue', marker='o', s=5)

# Set labels and title
plt.xlabel('Date/Time')
plt.ylabel('Value')
plt.title('Temperature and Humidity Variation Over Time')
plt.legend()
plt.grid(True)

# Show plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the weather dataset into a DataFrame
data = pd.read_csv('Weather Data.csv')

# Convert Date/Time column to datetime type
data['Date/Time'] = pd.to_datetime(data['Date/Time'])

# Extract the temperature values
temperature_values = data['Temp_C']

# Create a histogram to visualize the distribution of temperature values
plt.figure(figsize=(8, 6))
plt.hist(temperature_values, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Temperature Values')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load weather data from the CSV file
weather_data = pd.read_csv('Weather Data.csv').head(100)

# Stacked barplot
plt.figure(figsize=(10, 6))
sns.countplot(data=weather_data, x='Weather', hue='Wind Speed_km/h', palette='pastel')
plt.title('Stacked Bar Plot of Wind Speed by Weather',y=-0.4)
plt.xlabel('Weather')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Wind Speed (km/h)')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('Weather Data.csv')
# Joint plot of Temperature vs Wind Speed with hue for Weather
sns.jointplot(data=weather_data, x='Temp_C', y='Wind Speed_km/h', hue='Weather')
plt.xlabel('Temperature (C)')
plt.ylabel('Wind Speed (km/h)')
plt.subplots_adjust(top=0.8)
plt.suptitle('Joint Plot of Temperature vs Wind Speed by Weather', y=-0.1)

plt.show()

# %% [markdown]
# **Pair Plot of Temperature, Dew Point Temperature, and Relative Humidity**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# Load the dataset
weather_data = pd.read_csv('Weather Data.csv')
selected_columns = ['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%']
# Create a pair plot
sns.pairplot(weather_data[selected_columns], diag_kind='kde', plot_kws={'alpha': 0.6})
plt.suptitle('Pair Plot of Temperature, Dew Point Temperature, and Relative Humidity', fontsize=16)
plt.subplots_adjust(top=0.9)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
weather_data = pd.read_csv('Weather Data.csv')
numeric_columns = weather_data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_columns.corr()

plt.figure(figsize=(10, 8))

sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation Heatmap of Weather Data', fontsize=14, fontweight='bold')

plt.show()
